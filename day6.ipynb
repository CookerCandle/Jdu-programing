# %%
massiv = [4, 7, 10, 13, 16]

print(*[ x for x in massiv if x % 2 == 0])
# Out:
# 4 10 16

# %%
kortej = (12, 45, 67)

print(*kortej, sep="\n")
# Out:
# 12
# 45
# 67

# %%
massiv = [8, 22, 5, 17, 30]

print(f"Eng katta: {max(massiv)}\n"
      f"Eng kichik: {min(massiv)}")
# Out:
# Eng katta: 30
# Eng kichik: 5
