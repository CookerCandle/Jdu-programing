# %%
class Talaba:
    def __init__(self, ism, yosh, fakultet):
        self.ism = ism
        self.yosh = yosh
        self.fakultet = fakultet

    def talaba_malumot(self):
        return f"Talaba: {self.ism}, Yosh: {self.yosh}, Fakultet: {self.fakultet}"


talaba1 = Talaba("Ali", 20, "Dasturlash")
print(talaba1.talaba_malumot())
# Out:
# Talaba: Ali, Yosh: 20, Fakultet: Dasturlash

# %%
class Tortburchak:
    def __init__(self, uzunlik, kenglik):
        self.uzunlik = uzunlik
        self.kenglik = kenglik

    def yuzasi(self):
        return self.uzunlik * self.kenglik

    def perimetri(self):
        return 2 * (self.uzunlik + self.kenglik)


t1 = Tortburchak(4, 5)
print("Yuza:", t1.yuzasi())
print("Perimetr:", t1.perimetri())
# Out:
# Yuza: 20
# Perimetr: 18

# %%
class Hisoblagich:
    def __init__(self):
        self.__qiymat = 0

    def oshirish(self):
        self.__qiymat += 1

    def kamaytirish(self):
        self.__qiymat -= 1

    def qaytar(self):
        return self.__qiymat

h = Hisoblagich()
h.oshirish()
h.oshirish()
h.kamaytirish()
print("Hozirgi qiymat:", h.qaytar())
# Out:
# Hozirgi qiymat: 1
