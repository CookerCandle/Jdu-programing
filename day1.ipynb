# %%
# 3 vazifa
print(f"Salom, {input('ismingiz nima: ')}! Xush kelibsiz!")
# Out:
# Salom, Ali! Xush kelibsiz!

# %%
# 4 vazifa
print(f"Siz {2026 - int(input('Tugilgan yilingizni kiriting: '))} yoshdasiz! Hozirgi yil 2026-yil.")
# Out:
# Siz 20 yoshdasiz! Hozirgi yil 2026-yil.

# %%
# 5 vazifa
print(f"Siz quyidagi buyurmalarni berdingiz:\n"
      f"Taom: {input('Taom nomini kiriting: ')}\n"
      f"Ichimlik: {input('Ichimlik nomini kiriting: ')}\n"
      f"Desert: {input('Desert nomini kiriting: ')}")
# Out:
# Siz quyidagi buyurmalarni berdingiz:
# Taom: Osh
# Ichimlik: Coca Cola
# Desert: Tiramisu
