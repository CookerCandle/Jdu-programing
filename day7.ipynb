# %%
text = input("enter a text: ").split()
result = {}

for i in text:
    result[i] = result.get(i, 0) + 1
print(result)
# Out:
# {'bir': 1, 'ikki': 1, 'uch': 1}

# %%
user = {'name': 'Ali', 'age': 20, 'country': 'Uzbekistan'}
user['age'] = 21
del user['country']

print(user)
# Out:
# {'name': 'Ali', 'age': 21}

# %%
masiv = [1, 2, 2, 3, 4, 4, 5]

print(list(set(masiv)))
# Out:
# [1, 2, 3, 4, 5]
