# %%
from files.day13_1_vazifa import summa, ayirma

print(summa(5, 3))
print(ayirma(5, 3))
# Out:
# 8
# 2

# %%
from files.day13_2_vazifa import fizika, matematika

print(fizika.tezlik(100, 2))
print(fizika.masofa(50, 2))

print(matematika.qoshih(4, 5))
print(matematika.ayirma(10, 3))

# %%
import math

print(math.sqrt(16))
print(math.cos(0))
# Out:
# 4.0
# 1.0

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2026-08-05 11:20:46.207307
