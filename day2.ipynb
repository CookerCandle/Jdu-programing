# %%
# 3 vazifa
matn = input("Matn kiriting: ")

print(f"Matnning uzunligi: {len(matn)}\n"
      f"Katta harflar bilan: {matn.upper()}\n"
      f"Kichik harflar bilan: {matn.lower()}"
      )
# Out:
# Matnning uzunligi: 22
# Katta harflar bilan: PYTHON DASTURLASH TILI
# Kichik harflar bilan: python dasturlash tili

# %%
# 4 vazifa
print(f"Sizning shaxsiy profilingiz:\n"
      f"Ism: {input('Ismingizni kiriting: ')}\n"
      f"Familiya: {input('Familiyangizni kiriting: ')}")

yil = int(input("Tug'ilgan yilingizni kiriting: "))
print(f"Tug'ilgan yilingiz: {yil}\n"
      f"Yoshingiz: {2024 - yil}")
# Out:
# Sizning shaxsiy profilingiz:
# Ism: Dilshod
# Familiya: KArimov
# Tug'ilgan yilingiz: 1995
# Yoshingiz: 29

# %%
# 5 vazifa
matn = input("Matn kiriting: ")
print(f"Sozalr soni: {len(matn.split())}\n",
     f"Eng uzun so'z: {max(matn.split(), key=len)} ({len(max(matn.split(), key=len))} harf)\n",)
# Out:
# Sozalr soni: 5
#  Eng uzun so'z: dastulash (9 harf)
